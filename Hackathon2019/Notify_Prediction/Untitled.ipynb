# %%
from notify_run import Notify
notify = Notify()
notify.register()
# Out:
# Endpoint: https://notify.run/45X45HCxksN1FO69
# To subscribe, open: https://notify.run/c/45X45HCxksN1FO69
# Or scan this QR code:
